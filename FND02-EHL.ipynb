# %%
import turicreate

# %%
sf = turicreate.SFrame("~/my-env/data/home_data.sframe")

# %%
sf.show()
# Out:
# Materializing SFrame
# ...
# Further warnings of unsupported type will be suppressed.
# ...

# %%
sf.head()
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 10
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# ...

# %%
turicreate.show(sf["zipcode"],sf["price"])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %% [markdown]
# Zipcode 98039 is the neighborhood with highest housing price.
# From the chart above, (min, median, max) = (787500, 1905000, 6885000)

# %%
expensive = sf[sf['zipcode']=='98039']

# %%
expensive
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 3625049014 | 2014-08-29 00:00:00+00:00 | 2950000 |    4     |    3.5    |     4860    |
# | 2540700110 | 2015-02-12 00:00:00+00:00 | 1905000 |    4     |    3.5    |     4210    |
# | 3262300940 | 2014-11-07 00:00:00+00:00 |  875000 |    3     |     1     |     1220    |
# ...

# %%
expensive['price'].mean()
# Out:
# 2160606.5999999996

# %%
med_size = sf[(sf['sqft_living']>2000) & (sf['sqft_living']<=4000)]

# %%
len(med_size)
# Out:
# 9118

# %%
len(sf)
# Out:
# 21613

# %%
len(med_size)/len(sf)
# Out:
# 0.42187572294452413

# %%
training_set, test_set = sf.random_split(.8,seed=0)

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors','zipcode']
advanced_features = [ 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode','condition', 'grade', 'waterfront', 'view','sqft_above','sqft_basement','yr_built', 'yr_renovated', 'lat', 'long', 'sqft_living15', 'sqft_lot15', ]

# %%
my_features_model = turicreate.linear_regression.create(training_set,target='price',features=my_features,validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 115
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Training Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+---------------------------------+
# | 1         | 2        | 0.037381     | 3763208.270524     | 181908.848367                   |
# +-----------+----------+--------------+--------------------+---------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
advanced_features_model = turicreate.linear_regression.create(training_set, target = 'price', features = advanced_features,validation_set=None)
# Out:
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 17384
# Number of features          : 18
# Number of unpacked features : 18
# Number of coefficients    : 127
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+---------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Training Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+---------------------------------+
# | 1         | 2        | 0.034759     | 3469012.450663     | 154580.940735                   |
# +-----------+----------+--------------+--------------------+---------------------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>

# %%
print (my_features_model.evaluate(test_set))
# Out:
# {'max_error': 3486584.5093819317, 'rmse': 179542.43331269105}

# %%
print (advanced_features_model.evaluate(test_set))
# Out:
# {'max_error': 3556849.4138480965, 'rmse': 156831.1168019102}

# %%
179542.43331269105-156831.1168019102
# Out:
# 22711.31651078086
